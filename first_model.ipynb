# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import seaborn as sns
# %matplotlib inline
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\KJP\\Data Science\\cc_fraud'

# %%
# Load data

dataset = pd.read_csv("../toobig/cc_fraud_data/data.csv")

# %%
# Check for Null values
dataset.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
null_data = dataset[dataset.isnull().any(axis=1)]
null_data
# Out:
#             Time       V1        V2        V3        V4        V5        V6  \
# 271286  164505.0  1.79263 -1.247581 -2.565785 -0.535199  0.251652 -0.379364
#
#               V7    V8  V9  ...  V21  V22  V23  V24  V25  V26  V27  V28  \
# 271286  0.427056 -0.35 NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#         Amount  Class
# 271286     NaN    NaN
#
# [1 rows x 31 columns]

# %%
dataset = dataset.dropna()

# %%
g = sns.distplot(dataset["Time"], color="m", label="Skewness : %.2f"%(dataset["Time"].skew()))
g = g.legend(loc="best")

# %%
plt.figure(figsize = (20,15))
g = sns.heatmap(dataset.corr(), annot=True, fmt = ".2f", cmap = "coolwarm")

# %%
g = sns.FacetGrid(dataset, col='Class')
g = g.map(sns.distplot, "Time")
